# %%
import pandas as pd
import numpy as np
import os
import glob
import time

from datetime import datetime

from datetime import date, datetime, timezone

# %%
list_of_files = glob.glob(r'C:\Users\matthew.shuff\Downloads\*.xlsx') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getmtime)
print(latest_file)
# Out:
# C:\Users\matthew.shuff\Downloads\IFG Round 2 Bid.xlsx

# %%
excel_file = pd.ExcelFile(latest_file)
sheet_names = excel_file.sheet_names

print(sheet_names)
# Out:
# ['RFP Overview', '1. - Questions & Requirements', '2A. LTL Pricing Proposal', 'Sheet1', '2B. Truckload Pricing Proposal', '3. Fuel Schedule', '4. Accessorial Schedule', '5. Terms & Rebates']

# %%
df = pd.read_excel(latest_file, sheet_name='Sheet1')

# %% [markdown]
# df1['Target Ship (Late)'] = df1['Target Ship (Late)'].apply(lambda x: datetime.strptime(x, "%m/%d/%Y %I:%M%p"))

# %%
df.columns
# Out:
# Index(['Lane ID', 'Origin Zip', 'Destination Zip', 'Class', 'Quantity',
#        'Actual Quantity UOM', 'Average Pallet Length', 'Average Pallet Width',
#        'Average Pallet Height', 'Average Shipment Weight', 'Annual Load Count',
#        'Accessorial Description'],
#       dtype='object')

# %%
df['Accessorial Description'] = df['Accessorial Description'].str.upper()

# %%
substr = ('APP|HAZ|LIM|NOT|NPDEL|INSI|LIFT|RESI|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP')

df['Accessorial Description'] = df['Accessorial Description'].str.findall(substr)

# %%
df['Accessorial Description'].value_counts()
# Out:
# Accessorial Description
# [LIFT]                     325
# []                         311
# [APP]                      307
# [LIM, LIFT]                165
# [RESI]                     132
# [LIFT, APP]                 48
# [APP, RESI]                 42
# [RESI, APP]                 29
# [LIM]                       25
# [LIM, APP]                  22
# [RESI, LIFT]                15
# [LIFT, RESI]                15
# [APP, RESI, RESI]           14
# [RESI, APP, RESI]           12
# [APP, OVE]                  11
# [APP, LIFT]                  9
# [LIM, LIFT, APP]             9
# [APP, LIM]                   9
# [OVE, APP]                   7
# [LIFT, APP, RESI, RESI]      5
# [RESI, LIFT, APP]            4
# [APP, RESI, LIFT]            4
# [OVE]                        4
# [RESI, LIFT, APP, RESI]      4
# [LIFT, RESI, RESI]           3
# [LIM, LIFT, OVE]             3
# [RESI, RESI, APP]            3
# [APP, LIFT, RESI]            3
# [APP, LIM, LIFT]             2
# ...

# %%
df.to_excel('IFG2.xlsx')

# %%
df1 = df[df['Accessorial Description'].str.contains('APP|HAZ|LIM|NOT|NPDEL|INSI|LIFT|RES|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df1
# Out:
#       Origin Zip Destination Zip    PR Class  Quantity Actual Quantity UOM  \
# 0          45241           66101     1    70         4                 SKD
# 1          45241           66101     2    70         3                 SKD
# 2          76119           33617     3  92.5         6                 SKD
# 3          29388           21502     4   110         2                 SKD
# 7          48642           34748     8   150         5                 SKD
# ...          ...             ...   ...   ...       ...                 ...
# 1376       63132          V4M0B2  1377   125         1                 SKD
# 1377       63132          V5M3K4  1378   125         1                 SKD
# 1378       63132          V6T1Z3  1379   125         1                 SKD
# 1379       63132          V8L5X7  1380   125         1                 SKD
# 1380       63132          V9B1V9  1381   125         1                 SKD
#
# ...

# %%
df2 = df[df[1].str.contains('APP|HAZ|NPDEL|LIFT|RESP|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df3 = df[df[2].str.contains('APP|HAZ|NPDEL|LIFT|RESP|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df4 = df[df[3].str.contains('APP|HAZ|NPDEL|LIFT|RESP|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df5 = df[df[4].str.contains('APP|HAZ|NPDEL|LIFT|RESP|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df1['Accessorial Description'].value_counts()
# Out:
# Accessorial Description
#  APPOINTMENT                                                                                                                                                        187
# LIFT GATE DELIVERY (LFT2) ALL RISK (ARK)                                                                                                                            175
# LIFT GATE DELIVERY (LFT2)                                                                                                                                           118
#  APPOINTMENT                                                                                                                                                         75
# RESIDENTIAL DELIVERY (DEL1) ALL RISK (ARK)                                                                                                                           57
# ...

# %%
df2 = df2[['PR',1]]

# %%
df3 = df3[['PR',2]]

# %%
df4 = df4[['PR',3]]

# %%
df5 = df5[['PR',4]]

# %%
df6 = df1.merge(df2, how='outer', on='PR', indicator=True)

# %%
df7 = df6.merge(df3, how='outer',on='PR', indicator='Merged' )

# %%
df8 = df7.merge(df4, how='outer',on='PR', indicator='merged_4' )

# %%
df9 = df8.merge(df5, how='outer',on='PR', indicator='merged_5' )

# %%
df9.to_excel('3.9.26.xlsx')
