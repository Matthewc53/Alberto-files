# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
os.listdir(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Pandas Custom 2')
# Out:
# ["12-month Importing Data - CY '24 - Carrier Co_Joshua Trickel.xlsx",
#  '2023 Freight Lanes to Quote  (1)_Bryndan Blasingame.xlsx',
#  '2024 OUTBOUND_Jessica McTheeney.xlsx',
#  '2by2 Past Lanes_Matthew Zenchuk.xlsx',
#  '428 stores_Alexis Wallace - Copy.xlsx',
#  'AACT_red.xlsx',
#  'ABFS_red.xlsx',
#  'ADT_21_25.xlsx',
#  'ADT_3_10.xlsx',
#  'Ahmos.xlsx',
#  'alexclass.xlsx',
#  'Almco Steel Products Corp RFQ Freight 2025 Bl_Jenna Dewar.xlsx',
#  'Almco Steel Products Corp RFQ Freight 2025 Bl_Jenna Dewar_NTGRatesadded20%margin. .xlsx',
#  'Almcolineup.xlsx',
#  'Almcolineup2.xlsx',
#  'Ames Taping - Rerate - Edge Format - Item Level with Costs (1).xlsx',
#  'Ames.xlsx',
#  'Ameslineup2.xlsx',
#  'ATD - 2-20 THD 72 stores freight quote_Gregory Desgrosseill.xlsx',
#  'BID - LTL - FTL and Transfers_Tristan De Leon.xlsx',
#  'Bollards Plus LTL Pricing Workbook April 2024 (1) (1).xlsx',
#  'Broan - Rerate - Edge Format - Item Level with Costs (2).xlsx',
#  'Carlos.xlsx',
# ...

# %%
list_of_files = glob.glob(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Pandas Custom 2\*') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getmtime)
print(latest_file)
# Out:
# C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Pandas Custom 2\Shipping 01_29_2025.xlsx

# %%
df = pd.read_excel(latest_file, sheet_name='Product Details')

# %%
cnts = df['Shipment ID'].value_counts()

# %%
cnts = pd.DataFrame(cnts)

# %%
cnts['ID #']=cnts.index

# %%
merged = df.merge(cnts,left_on='Shipment ID',right_on='ID #')

# %%
merged = merged[merged['count_x']>1]

# %% [markdown]
# merged = merged.set_index(['Shipment ID','Rate']).head(60)

# %%
merged.drop_duplicates(subset='Rate')
# Out:
#                               Shipment ID  H/U type      O      D  count_x  \
# 31   36e89011-b44c-42f4-8a84-20d7079bec7e       NaN  08876  75092        4
# 55   09de65c6-444f-4d85-86c0-f3ba2b7d491b       NaN  33317  77092        4
# 59   1d5413d9-d968-49c7-a034-c76e69d3b534       NaN  33317  08876        3
# 86   aa3cacaf-b938-436a-a9fe-71c79aeac14d       NaN  08876  04966        2
# 87   aa3cacaf-b938-436a-a9fe-71c79aeac14d       NaN  08876  04966        2
# 98   53e7bac4-5481-48ea-83a7-56e66344a5d1       NaN  77092  70123        2
# 111  bd1e0be3-0e89-415f-afa7-b6b557d12212       NaN  77092  08876        2
# 130  f1d2f51e-5e4d-42cd-b937-2fcb83bcbd20       NaN  90723  77092        2
# 157  fecc9b8b-bcf5-40f6-bc21-8160c072809d       NaN  08876  70123        2
# 170  1cd57821-9f2a-423b-a2b9-72828274e89b       NaN  77092  11788        2
# 228  9817899a-2938-48b8-8fa1-f02f859867d9       NaN  08876  77092        2
# ...

# %%
merged.groupby(['Shipment ID','Rate']).sum().head(60)
