# %%
import pandas as pd
import numpy as np
import os
import glob
import time

from datetime import datetime

from datetime import date, datetime, timezone

# %%
list_of_files = glob.glob(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Edge\*.xls') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getmtime)
print(latest_file)
# Out:
# C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Edge\edge template_ANWIL.xls

# %%
excel_file = pd.ExcelFile(latest_file)
sheet_names = excel_file.sheet_names

print(sheet_names)
# Out:
# ['Shipment_Edge']

# %%
df = pd.read_excel(latest_file)

# %% [markdown]
# df1['Target Ship (Late)'] = df1['Target Ship (Late)'].apply(lambda x: datetime.strptime(x, "%m/%d/%Y %I:%M%p"))

# %%
df.columns
# Out:
# Index(['Primary Reference', 'Mode', 'Target Ship (Early)', 'Payment Terms',
#        'Origin City', 'Origin State', 'Paste oZip', 'Paste dZip', 'Origin Zip',
#        'Dest Zip', 'Item Weight', 'Item Class', 'Origin Ctry', 'Dest City',
#        'Dest State', 'Dest Ctry', 'Services', 'Item Quantity', 'Item Length',
#        'Item Width', 'Item Height', 'Dimensions UOM', '#', 'Group'],
#       dtype='object')

# %%
df1 = df[df['Services'].str.contains('APP|HAZ|LIM|NOT|NPDEL|INSI|LIFT|RES|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df1['Services'].value_counts()
# Out:
# Services
# LIFTD,RESD,APP          29
# APP                     29
# NPDEL                   20
# LIFTD                   20
# APP,LADL                15
# RESD,APP                12
# LIFTD,NPDEL,RESD        11
# LIFTD,APP                9
# LIFTD,APP,LADL           9
# LADL                     8
# LIFTD,NPDEL              5
# NPDEL,LADL               5
# LIFTD,RESD               2
# NPDEL,RESD               2
# RESD                     2
# LIFTD,LADL               1
# NPDEL,RESD,APP           1
# LIFTD,NPDEL,RESD,APP     1
# LIFTD,NPDEL,LADL         1
# Name: count, dtype: int64

# %%
df1['Services'] = df1['Services'].str.replace('APP','APTD')
    
df1['Services'] = df1['Services'].str.replace('LIFTD','LFTD')

df1['Services'] = df1['Services'].str.replace('LADL','LTDAD')
    
df1['Services'] = df1['Services'].str.replace('LAPU','LTDAP')
        
df1['Services'] = df1['Services'].str.replace('RESD','RES')

df1['Services'] = df1['Services'].str.replace('NPDEL','MNC')

df1['Services'] = df1['Services'].str.replace('NPDEL','MNC')

df1['Services'] = df1['Services'].str.replace('IDEL','IDL')

df1['Services'] = df1['Services'].str.replace(';','|')

df1['Services'] = df1['Services'].str.replace(',','|')
# Out:
# C:\Users\matthew.shuff\AppData\Local\Temp\ipykernel_25988\2125096699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Services'] = df1['Services'].str.replace('APP','APTD')
# C:\Users\matthew.shuff\AppData\Local\Temp\ipykernel_25988\2125096699.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Services'] = df1['Services'].str.replace('LIFTD','LFTD')
# C:\Users\matthew.shuff\AppData\Local\Temp\ipykernel_25988\2125096699.py:5: SettingWithCopyWarning:
# ...

# %%
df1
# Out:
#     Primary Reference Mode Target Ship (Early) Payment Terms  Origin City  \
# 8          FP00298754  LTL          2026-04-29    ThirdParty          NaN
# 9          FP00298771  LTL          2026-04-29    ThirdParty          NaN
# 10         FP00298773  LTL          2026-04-29    ThirdParty          NaN
# 13         FP00298654  LTL          2026-04-29    ThirdParty          NaN
# 15         FP00298647  LTL          2026-04-29    ThirdParty          NaN
# ..                ...  ...                 ...           ...          ...
# 404        FP00293255  LTL          2026-04-29    ThirdParty          NaN
# 405        FP00293267  LTL          2026-04-29    ThirdParty          NaN
# 406        FP00293269  LTL          2026-04-29    ThirdParty          NaN
# 407        FP00293272  LTL          2026-04-29    ThirdParty          NaN
# 409        FP00293363  LTL          2026-04-29    ThirdParty          NaN
#
#      Origin State  Paste oZip Paste dZip  Origin Zip  Dest Zip  ...  \
# ...

# %%
df1.to_csv('4_29.csv')

# %%
df2 = df[df[2].str.contains('APP',na=False)]

# %%
df3 = df[df[3].str.contains('APP|HAZ|NPDEL|LIFT|RESP|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df4 = df[df[4].str.contains('APP|HAZ|NPDEL|LIFT|RESP|OVE|RESD|LADL|LAP|IDEL|IPUP|LAP',na=False)]

# %%
df2 = df2[['Pro Number',2]]

# %%
df3 = df3[['Pro Number',3]]

# %%
df4 = df4[['Pro Number',4]]

# %%
df5 = df1.merge(df2, how='outer', on='Pro Number', indicator=True)

# %%
df6 = df5.merge(df3, how='outer',on='Pro Number', indicator='Merged' )

# %%
df7 = df6.merge(df4, how='outer',on='Pro Number', indicator='merged_4' )

# %%
df7.to_excel('TI_1_21.xlsx')
