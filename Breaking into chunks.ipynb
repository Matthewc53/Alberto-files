# %%
import pandas as pd

import numpy as np

import glob

import os

# %%
#read in chunk folder fns

list_of_files = glob.glob(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\SMC\*.csv') # * means all if need specific format then *.csv
latest_file_edg = max(list_of_files, key=os.path.getmtime)
print(latest_file_edg)
# Out:
# C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\SMC\SMC_Input File_TE_Conn.csv

# %%
df = pd.read_csv(latest_file_edg)
# Out:
# C:\Users\matthew.shuff\AppData\Local\Temp\ipykernel_9200\3195239348.py:1: DtypeWarning: Columns (4,21,22,29,37,38,45,46,53,54,61,62,69,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(latest_file_edg)

# %%
length = len(df)

# %%
length
# Out:
# 14588

# %%
df
# Out:
#        shipmentID  pickupDate  originCity  originStateProvince  \
# 0               1    20260512         NaN                  NaN
# 1               2    20260512         NaN                  NaN
# 2               3    20260512         NaN                  NaN
# 3               4    20260512         NaN                  NaN
# 4               5    20260512         NaN                  NaN
# ...           ...         ...         ...                  ...
# 14583       14584    20260512         NaN                  NaN
# 14584       14585    20260512         NaN                  NaN
# 14585       14586    20260512         NaN                  NaN
# 14586       14587    20260512         NaN                  NaN
# 14587       14588    20260512         NaN                  NaN
#
#       originPostalCode originCountry  destinationCity  \
# 0                35020           USA              NaN
# 1                35601           USA              NaN
# ...

# %%
df['Origin Zip'] = df['Origin Zip'].apply(str)

df['Dest Zip'] = df['Dest Zip'].apply(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origin Zip'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['originPostalCode']=df['originPostalCode'].apply(str)

df['destinationPostalCode']=df['destinationPostalCode'].apply(str)

# %%
df['Dest Zip'].dtypes
# Out:
# dtype('O')

# %%
df['Origin Zip'] = df['Origin Zip'].str.zfill(5)

df['Dest Zip'] = df['Dest Zip'].str.zfill(5)

# %%
df['originPostalCode']=df['originPostalCode'].str.zfill(5)

df['destinationPostalCode']=df['destinationPostalCode'].str.zfill(5)

# %%
df.head(60)
# Out:
#     shipmentID  pickupDate  originCity  originStateProvince originPostalCode  \
# 0            1    20260512         NaN                  NaN            35020
# 1            2    20260512         NaN                  NaN            35601
# 2            3    20260512         NaN                  NaN            35758
# 3            4    20260512         NaN                  NaN            35811
# 4            5    20260512         NaN                  NaN            35824
# 5            6    20260512         NaN                  NaN            35824
# 6            7    20260512         NaN                  NaN            35601
# 7            8    20260512         NaN                  NaN            35601
# 8            9    20260512         NaN                  NaN            35601
# 9           10    20260512         NaN                  NaN            35758
# 10          11    20260512         NaN                  NaN            35758
# ...

# %%
#of chunks is denominator

chnk_sz = length/3

# %%
chnk_sz = round(chnk_sz)

# %%
chnk_sz
# Out:
# 4863

# %%
chnk1 = df.loc[:chnk_sz]

# %%
chnk1
# Out:
#       shipmentID  pickupDate  originCity  originStateProvince  \
# 0              1    20260512         NaN                  NaN
# 1              2    20260512         NaN                  NaN
# 2              3    20260512         NaN                  NaN
# 3              4    20260512         NaN                  NaN
# 4              5    20260512         NaN                  NaN
# ...          ...         ...         ...                  ...
# 4859        4860    20260512         NaN                  NaN
# 4860        4861    20260512         NaN                  NaN
# 4861        4862    20260512         NaN                  NaN
# 4862        4863    20260512         NaN                  NaN
# 4863        4864    20260512         NaN                  NaN
#
#      originPostalCode originCountry  destinationCity  \
# 0               35020           USA              NaN
# 1               35601           USA              NaN
# 2               35758           USA              NaN
# ...

# %%
chnk2 = df.loc[chnk_sz+1:chnk_sz*2]

# %%
chnk_sz_3 = (chnk_sz*2)+1

# %%
chnk2
# Out:
#       shipmentID  pickupDate  originCity  originStateProvince  \
# 4864        4865    20260512         NaN                  NaN
# 4865        4866    20260512         NaN                  NaN
# 4866        4867    20260512         NaN                  NaN
# 4867        4868    20260512         NaN                  NaN
# 4868        4869    20260512         NaN                  NaN
# ...          ...         ...         ...                  ...
# 9722        9723    20260512         NaN                  NaN
# 9723        9724    20260512         NaN                  NaN
# 9724        9725    20260512         NaN                  NaN
# 9725        9726    20260512         NaN                  NaN
# 9726        9727    20260512         NaN                  NaN
#
#      originPostalCode originCountry  destinationCity  \
# 4864            27617           USA              NaN
# 4865            27804           USA              NaN
# 4866            28152           USA              NaN
# ...

# %%
chnk3 = df.loc[chnk_sz_3:chnk_sz*3]

# %%
chnk_sz_4 = (chnk_sz*3)+1

chnk_sz_5 = (chnk_sz*4)+1

chnk_sz_6 = (chnk_sz*5)+1

chnk_sz_7 = (chnk_sz*6)+1

chnk_sz_8 = (chnk_sz*7)+1

chnk_sz_9 = (chnk_sz*8)+1

chnk_sz_10 = (chnk_sz*9)+1

chnk_sz_11 = (chnk_sz*10)+1

chnk_sz_12 = (chnk_sz*11)+1

chnk_sz_13 = (chnk_sz*12)+1

chnk_sz_14 = (chnk_sz*13)+1

chnk_sz_15 = (chnk_sz*14)+1

# %%
chnk4 = df.loc[chnk_sz_4:chnk_sz*4]

chnk5 = df.loc[chnk_sz_5:chnk_sz*5]

chnk6= df.loc[chnk_sz_6:chnk_sz*6]

chnk7= df.loc[chnk_sz_7:chnk_sz*7]

chnk8= df.loc[chnk_sz_8:chnk_sz*8]

chnk9= df.loc[chnk_sz_9:chnk_sz*9]

chnk10= df.loc[chnk_sz_10:chnk_sz*10]

chnk11= df.loc[chnk_sz_11:chnk_sz*11]

chnk12= df.loc[chnk_sz_12:chnk_sz*12]

chnk13= df.loc[chnk_sz_13:chnk_sz*13]

chnk14= df.loc[chnk_sz_14:chnk_sz*14]

chnk15= df.loc[chnk_sz_15:chnk_sz*15]

# %%
chnk1.to_csv(r'..\comb_fl\TEC_1.csv',index=False)

chnk2.to_csv(r'..\comb_fl\TEC_2.csv',index=False)

chnk3.to_csv(r'..\comb_fl\TEC_3.csv',index=False)

#chnk4.to_excel(r'..\comb_fl\827_2_4.xls',sheet_name='Shipment_Edge', engine='openpyxl',index=False)

#chnk5.to_excel(r'..\comb_fl\824_5.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk6.to_excel(r'..\comb_fl\824_6.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk7.to_excel(r'..\comb_fl\785_7.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk8.to_excel(r'..\comb_fl\785_85.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

# %%
chnk1.to_csv(r'..\comb_fl\TEC_1.csv',sheet_name='Shipment_Edge', engine='openpyxl',index=False)

chnk2.to_csv(r'..\comb_fl\TEC_2.csv',sheet_name='Shipment_Edge', engine='openpyxl',index=False)

chnk3.to_csv(r'..\comb_fl\TEC_3.csv',sheet_name='Shipment_Edge', engine='openpyxl',index=False)

#chnk4.to_excel(r'..\comb_fl\827_2_4.xls',sheet_name='Shipment_Edge', engine='openpyxl',index=False)

#chnk5.to_excel(r'..\comb_fl\824_5.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk6.to_excel(r'..\comb_fl\824_6.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk7.to_excel(r'..\comb_fl\785_7.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk8.to_excel(r'..\comb_fl\785_85.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 chnk1.to_csv(r'..\comb_fl\TEC_1.csv',sheet_name='Shipment_Edge', engine='openpyxl',index=False)
#       3 chnk2.to_csv(r'..\comb_fl\TEC_2.csv',sheet_name='Shipment_Edge', engine='openpyxl',index=False)
#       5 chnk3.to_csv(r'..\comb_fl\TEC_3.csv',sheet_name='Shipment_Edge', engine='openpyxl',index=False)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'sheet_name'

# %%
#chnk9.to_excel(r'..\comb_fl\785_9.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk10.to_excel(r'..\comb_fl\785_10.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

#chnk11.to_excel(r'..\comb_fl\785_11.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

chnk12.to_excel(r'..\comb_fl\785_12.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

chnk13.to_excel(r'..\comb_fl\785_13.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

chnk14.to_excel(r'..\comb_fl\785_14.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

chnk15.to_excel(r'..\comb_fl\785_15.xls',sheet_name='Shipment_Edge',engine='openpyxl',index=False)

# %%
chnk2.to_excel(r'comb_fl\joann2.xlsx',index=False)

# %%
chnk2.to_excel(r'comb_fl\joann2.xlsx',index=False)

# %%
chnk2.to_excel(r'comb_fl\joann2.xlsx',index=False)

# %%
chnk5.to_excel(r'edge\GPI5.xlsx',index=False)

chnk6.to_excel(r'edge\GPI6.xlsx',index=False)

chnk7.to_excel(r'edge\GPI7.xlsx',index=False)

chnk8.to_excel(r'edge\GPI8.xlsx',index=False)

chnk9.to_excel(r'edge\GPI9.xlsx',index=False)

chnk10.to_excel(r'edge\GPI10.xlsx',index=False)

# %%
chnk5.to_excel("comb_fl\chunkedfile5.xlsx",index=False)

# %%
#df = np.array_split(df, 5)

# %% [markdown]
# # combining edge extracts

# %%
import xlwings as xw

# %%
wb = xw.Book('comb_fl\Broan1.xlsx')

wb2 = xw.Book('edge\edge template.xls')

# %%
first_sheet_end = wb.sheets[0].range('A1').end('down').row

# %%
first_sheet_end = str(first_sheet_end)

# %%
copypr = wb.sheets[0].range('A2:'+ 'A' + first_sheet_end)

copywgt = wb.sheets[0].range('B2:'+ 'B' + first_sheet_end)

copycl = wb.sheets[0].range('C2:'+ 'C' + first_sheet_end)

copyor = wb.sheets[0].range('I2:'+ 'I' + first_sheet_end)

copydest = wb.sheets[0].range('J2:'+ 'J' + first_sheet_end)

copyplt = wb.sheets[0].range('F2:'+ 'F' + first_sheet_end)

# %%
ltl_end = wb2.sheets[0].range('D1').end('down').row

# %%
ltl_end

# %%
copypr.copy()

wb2.sheets[0].range("A2").paste(paste='values')


copywgt.copy()

wb2.sheets[0].range("B2").paste(paste='values')
