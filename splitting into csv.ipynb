# %%
import pandas as pd

import numpy as np

import os

# %%
os.listdir(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Pandas_source_files')
# Out:
# ['2024 GRI List of US High Cost Service Areas Final (1).xlsx',
#  'Echo-ADM-RRL 30 day_Anastasia Letosky.xlsx',
#  'Farmer Brothers 2024 RFP LTL Rate Submission File (2).xlsx',
#  'Farmer Brothers results (1).xlsx',
#  'FWDA_HCD_src_fl.xlsx',
#  'KING SOLOMON ENTERPRISES, INC._Anastasia Letosky.xlsx',
#  'MCG Data 11-1-23 thru 1-31-24 with NTG and exceptions (2).xlsx',
#  'Moog CTSI LTL Data Nov 2023 thru Jan 2024 NTG results-exceptions.xlsx',
#  'Rating_Report_true.xls',
#  'S62B - LTL Volume Out 11 and 41_Kelsey Tapia.xlsx',
#  'Shipping 04_03_2024_Kekoa Carville.xlsx',
#  'True Fitness 2023 Data_Chi An Chen_4vs.xls',
#  'zipsfor_myles_transport.xlsx']

# %%
df = pd.read_excel('Pandas_source_files\True Fitness 2023 Data_Chi An Chen_4vs.xls')

# %%
df1 = pd.read_excel('Pandas_source_files\Rating_Report_true.xls')

# %%
df1['Carrier SCAC'] = df1['Carrier SCAC'].str.strip()

# %%
df1['Carrier SCAC'].value_counts()
# Out:
# Carrier SCAC
# FXNL    1569
# RLCA    1555
# UPGF    1534
# FWDA    1489
# Name: count, dtype: int64

# %%
df1_fwda = df1[df1['Carrier SCAC']=='FWDA']

# %%
df1_fwda
# Out:
#       OID  Primary Reference     Type  Lane ID     Carrier Name Carrier SCAC  \
# 0     NaN           13108493  Carrier      NaN  FORWARD AIR INC         FWDA
# 4     NaN           13122315  Carrier      NaN  FORWARD AIR INC         FWDA
# 8     NaN           13108492  Carrier      NaN  FORWARD AIR INC         FWDA
# 12    NaN           13122316  Carrier      NaN  FORWARD AIR INC         FWDA
# 16    NaN           13108491  Carrier      NaN  FORWARD AIR INC         FWDA
# ...   ...                ...      ...      ...              ...          ...
# 6124  NaN           13050515  Carrier      NaN  FORWARD AIR INC         FWDA
# 6128  NaN           13050518  Carrier      NaN  FORWARD AIR INC         FWDA
# 6132  NaN           13106137  Carrier      NaN  FORWARD AIR INC         FWDA
# 6139  NaN           13106138  Carrier      NaN  FORWARD AIR INC         FWDA
# 6143  NaN           13050519  Carrier      NaN  FORWARD AIR INC         FWDA
#
# ...

# %%
df1_fxnl = df1[df1['Carrier SCAC']=='FXNL']df

# %%
df1_rlca = df1[df1['Carrier SCAC']=='RLCA']

# %%
df1_upgf = df1[df1['Carrier SCAC']=='UPGF']

# %%
df1_fxnl = df
# Out:
#       OID  Primary Reference     Type  Lane ID    Carrier Name Carrier SCAC  \
# 3     NaN           13108493  Carrier      NaN  TFORCE FREIGHT         UPGF
# 7     NaN           13122315  Carrier      NaN  TFORCE FREIGHT         UPGF
# 11    NaN           13108492  Carrier      NaN  TFORCE FREIGHT         UPGF
# 15    NaN           13122316  Carrier      NaN  TFORCE FREIGHT         UPGF
# 19    NaN           13108491  Carrier      NaN  TFORCE FREIGHT         UPGF
# ...   ...                ...      ...      ...             ...          ...
# 6131  NaN           13050518  Carrier      NaN  TFORCE FREIGHT         UPGF
# 6135  NaN           13106137  Carrier      NaN  TFORCE FREIGHT         UPGF
# 6138  NaN           13050517  Carrier      NaN  TFORCE FREIGHT         UPGF
# 6142  NaN           13106138  Carrier      NaN  TFORCE FREIGHT         UPGF
# 6146  NaN           13050519  Carrier      NaN  TFORCE FREIGHT         UPGF
#
# ...

# %%
df1_fwda.to_csv('df_fwda.csv')

# %%
df1_rlca.to_csv('df1_rlca.csv')

# %%
df1_upgf.to_csv('upgf.csv')

# %%
df1_fxnl.to_csv('fxnl.csv')

# %%
df.rename(columns=df.iloc[0], inplace = True)

# %%
df = df.iloc[1:]

# %%
df
