# %%
import os

import pandas as pd

import numpy as np

import glob

# %%
list_of_files = glob.glob(r'C:\Users\matthew.shuff\AppData\Local\Temp\*.xls') # * means all if need specific format then *.csv
latest_edge_file = max(list_of_files, key=os.path.getctime)
print(latest_edge_file)
# Out:
# C:\Users\matthew.shuff\AppData\Local\Temp\Rating_Report_2026_05_12_10_13_00.xls

# %%
1
list_of_files = glob.glob(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\SMC\SMC output\*') # * means all if need specific format then *.csv
2
latest_edge_file = max(list_of_files, key=os.path.getctime)
3
print(latest_edge_file)
# Out:
# C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\SMC\SMC output\437766-aggregate-38c896a6-05e0-4519-a081-e0cac19349e413515977874349758528.csv

# %%
latest_edge_file

# %%
sorted_files = sorted(list_of_files, key=os.path.getmtime)

# %%
one = sorted_files[-1]

# %%
one
# Out:
# 'C:\\Users\\matthew.shuff\\OneDrive - Nolan Transportation Group\\Desktop\\SMC\\SMC output\\437766-aggregate-c0a46170-d950-49ee-887d-d64ded77be646314292942534250358.csv'

# %%
two = sorted_files[-2]
three = sorted_files[-3]
four = sorted_files[-4]

# %%
one = pd.read_excel(one)

two = pd.read_excel(two)

three = pd.read_excel(three)

four = pd.read_excel(four)

# %%
one = pd.read_csv(one,skiprows=4)

two = pd.read_csv(two,skiprows=4)

three = pd.read_csv(three,skiprows=4)

four = pd.read_csv(four,skiprows=4)

# %%
two

# %%
combined = pd.concat([one,two,three])

# %%
combined
# Out:
#                     C1 = Transportation Insight, LLC
# 0               Bill To = NOLAN TRANSPORTATION GROUP
# 1                                                NaN
# 2  Transaction ID = c0a46170-d950-49ee-887d-d64de...
# 0               Bill To = NOLAN TRANSPORTATION GROUP
# 1                                                NaN
# 2  Transaction ID = 39b4788a-5237-487a-b782-7e4f4...
# 0               Bill To = NOLAN TRANSPORTATION GROUP
# 1                                                NaN
# 2  Transaction ID = 38c896a6-05e0-4519-a081-e0cac...

# %%
combined.to_excel('5.11.26.xlsx')
