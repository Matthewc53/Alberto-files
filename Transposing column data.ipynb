# %%
import pandas as pd

import numpy as np

import os

# %%
os.listdir(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Python Outputs')

# %%
df = pd.read_excel('Python Outputs\Stevens file.xlsx')

# %%
df

# %%
df1 = df[df['LTL 1-10 Pallets / Price Per Pallet']==1]

df2 = df[df['LTL 1-10 Pallets / Price Per Pallet']==2]

df3 = df[df['LTL 1-10 Pallets / Price Per Pallet']==3]

df4 = df[df['LTL 1-10 Pallets / Price Per Pallet']==4]

df5 = df[df['LTL 1-10 Pallets / Price Per Pallet']==5]

df6 = df[df['LTL 1-10 Pallets / Price Per Pallet']==6]

df7 = df[df['LTL 1-10 Pallets / Price Per Pallet']==7]

df8 = df[df['LTL 1-10 Pallets / Price Per Pallet']==8]

# %%
df_ind = df1.index.tolist

# %%
df1['P1 Rate'] = df1['P1-8']

df1['P1 SCAC'] = df1['Unnamed: 10']

# %%
df2['P2 Rate'] = df2['P1-8']

df2['P2 SCAC'] = df2['Unnamed: 10']

# %%
df3['P3 Rate'] = df3['P1-8']

df3['P3 SCAC'] = df3['Unnamed: 10']

# %%
df4['P4 Rate'] = df4['P1-8']

df4['P4 SCAC'] = df4['Unnamed: 10']

# %%
df5['P5 Rate'] = df5['P1-8']

df5['P5 SCAC'] = df5['Unnamed: 10']

# %%
df6['P6 Rate'] = df6['P1-8']

df6['P6 SCAC'] = df6['Unnamed: 10']

# %%
df7['P7 Rate'] = df7['P1-8']

df7['P7 SCAC'] = df7['Unnamed: 10']

# %%
df8['P8 Rate'] = df8['P1-8']

df8['P8 SCAC'] = df8['Unnamed: 10']

# %%
df1['P2 Rates'] = df2['P2 Rate'].values

df1['P2 SCAC'] = df2['P2 SCAC'].values

df1['P3 Rates'] = df3['P3 Rate'].values

df1['P3 SCAC'] = df3['P3 SCAC'].values

df1['P4 Rates'] = df4['P4 Rate'].values

df1['P4 SCAC'] = df4['P4 SCAC'].values

df1['P5 Rates'] = df5['P5 Rate'].values

df1['P5 SCAC'] = df5['P5 SCAC'].values

df1['P6 Rates'] = df6['P6 Rate'].values

df1['P6 SCAC'] = df6['P6 SCAC'].values

df1['P7 Rates'] = df7['P7 Rate'].values

df1['P7 SCAC'] = df7['P7 SCAC'].values

df1['P8 Rates'] = df8['P8 Rate'].values

df1['P8 SCAC'] = df8['P8 SCAC'].values

# %%
df1

# %%
df1.to_excel('Merkel_merged_fn.xlsx')

# %%
merged = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
merged

# %%
merged.to_excel('stevens_merged_out.xlsx')

# %%
os.listdir(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Pandas_source_files')

# %%
data = pd.read_excel('Pandas_source_files\LTL for LCL BID 4-19-24.xlsx')

rating = pd.read_excel('Pandas_source_files\Rating_Report_2024_04_22_11_29_36.xls')

# %%
data
# Out:
#    2024 LCL Pricing Worksheet    Unnamed: 1   Unnamed: 2      Unnamed: 3  \
# 0                         NaN           NaN          NaN             NaN
# 1                        Lane       Service  Origin Port  Origin Country
# 2                           1  PORT TO DOOR     HAIPHONG              VN
# 3                           2  PORT TO DOOR  HO CHI MINH              VN
# 4                           3  PORT TO DOOR        BUSAN              KR
# ..                        ...           ...          ...             ...
# 81                         80  PORT TO DOOR     SHANGHAI              CN
# 82                         81  PORT TO DOOR        TOKYO              JP
# 83                         82  PORT TO DOOR       XIAMEN              CN
# 84                         83  PORT TO DOOR      YANTIAN              CN
# 85                        NaN           NaN          NaN             NaN
#
#               Unnamed: 4 Unnamed: 5  \
# 0                    NaN        NaN
# ...

# %%
data = data.iloc[1:]

# %%
data.rename(columns=data.iloc[0], inplace = True)
# Out:
# C:\Users\matthew.shuff\AppData\Local\Temp\ipykernel_18604\3079831275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns=data.iloc[0], inplace = True)

# %%
data = data.iloc[1:]

# %%
data = data.fillna(0)

# %%
data
# Out:
#    Lane       Service  Origin Port Origin Country                US CFS  \
# 2     1  PORT TO DOOR     HAIPHONG             VN  Elizabeth, NJ  07201
# 3     2  PORT TO DOOR  HO CHI MINH             VN  Elizabeth, NJ  07201
# 4     3  PORT TO DOOR        BUSAN             KR                     0
# 5     4  PORT TO DOOR    HONG KONG             HK  Elizabeth, NJ  07201
# 6     5  PORT TO DOOR    KAOHSIUNG             TW  Elizabeth, NJ  07201
# ..  ...           ...          ...            ...                   ...
# 81   80  PORT TO DOOR     SHANGHAI             CN                     0
# 82   81  PORT TO DOOR        TOKYO             JP                     0
# 83   82  PORT TO DOOR       XIAMEN             CN                     0
# 84   83  PORT TO DOOR      YANTIAN             CN                     0
# 85    0             0            0              0                     0
#
#       zip Destination Door (Refer to address  RFQ Location Tab)    zip  \
# ...

# %%
data.Lane = data.Lane.apply(int)

# %%
rating
# Out:
#     OID  Primary Reference     Type  Lane ID  \
# 0   NaN                 22  Carrier      NaN
# 1   NaN                 44  Carrier      NaN
# 2   NaN                 23  Carrier      NaN
# 3   NaN                 24  Carrier      NaN
# 4   NaN                 25  Carrier      NaN
# 5   NaN                 47  Carrier      NaN
# 6   NaN                 49  Carrier      NaN
# 7   NaN                 28  Carrier      NaN
# 8   NaN                 50  Carrier      NaN
# 9   NaN                 51  Carrier      NaN
# 10  NaN                 30  Carrier      NaN
# 11  NaN                 52  Carrier      NaN
# 12  NaN                 31  Carrier      NaN
# 13  NaN                 10  Carrier      NaN
# 14  NaN                 54  Carrier      NaN
# 15  NaN                 11  Carrier      NaN
# 16  NaN                 33  Carrier      NaN
# 17  NaN                 55  Carrier      NaN
# 18  NaN                 12  Carrier      NaN
# 19  NaN                 34  Carrier      NaN
# ...

# %%
merged = data.merge(rating, left_on='Lane', right_on='Primary Reference')

# %%
merged
# Out:
#     Lane       Service   Origin Port Origin Country                  US CFS  \
# 0      1  PORT TO DOOR      HAIPHONG             VN    Elizabeth, NJ  07201
# 1      2  PORT TO DOOR   HO CHI MINH             VN    Elizabeth, NJ  07201
# 2      4  PORT TO DOOR     HONG KONG             HK    Elizabeth, NJ  07201
# 3      5  PORT TO DOOR     KAOHSIUNG             TW    Elizabeth, NJ  07201
# 4      6  PORT TO DOOR       KEELUNG             TW    Elizabeth, NJ  07201
# 5      8  PORT TO DOOR        MANILA             PH    Elizabeth, NJ  07201
# 6     10  PORT TO DOOR        NINGBO             CN    Elizabeth, NJ  07201
# 7     11  PORT TO DOOR      SHANGHAI             CN    Elizabeth, NJ  07201
# 8     12  PORT TO DOOR       YANTIAN             CN    Elizabeth, NJ  07201
# 9     18  PORT TO DOOR       BANGKOK             TH  Los Angeles, CA  90220
# 10    20  PORT TO DOOR        FUZHOU             CN  Los Angeles, CA  90220
# ...

# %%
merged.to_excel('lcl_bid.xlsx')

# %%
os.listdir(r'C:\Users\matthew.shuff\OneDrive - Nolan Transportation Group\Desktop\Pandas_source_files')
# Out:
# ['2024 GRI List of US High Cost Service Areas Final (1).xlsx',
#  'Echo-ADM-RRL 30 day_Anastasia Letosky.xlsx',
#  'Farmer Brothers 2024 RFP LTL Rate Submission File (2).xlsx',
#  'Farmer Brothers results (1).xlsx',
#  'Freightview_shipments_5c672cb8a75f15000491c0d_Ahmos III Zu-Bolton.xlsx',
#  'FWDA_HCD_src_fl.xlsx',
#  'KING SOLOMON ENTERPRISES, INC._Anastasia Letosky.xlsx',
#  'LTL for LCL BID 4-19-24.xlsx',
#  'Marken LLP St. Pete LTL Pricing_Steven Dutton.xlsx',
#  'MCG Data 11-1-23 thru 1-31-24 with NTG and exceptions (2).xlsx',
#  'Moog CTSI LTL Data Nov 2023 thru Jan 2024 NTG results-exceptions.xlsx',
#  'NTG PROPOSAL 3182024 (1).xlsx',
#  'Rating_Report_2024_04_22_11_29_36.xls',
#  'Rating_Report_true.xls',
#  'S62B - LTL Volume Out 11 and 41_Kelsey Tapia.xlsx',
#  'Shipping 04_03_2024_Kekoa Carville.xlsx',
#  'Shipping 04_16_2024_Khalil Walker.xlsx',
#  'True Fitness 2023 Data_Chi An Chen_4vs.xls',
#  'zipsfor_myles_transport.xlsx']

# %%
df = pd.read_excel('Pandas_source_files/NTG PROPOSAL 3182024 (1).xlsx')

# %%
df.Ref.value_counts().head(60)
# Out:
# Ref
# 37087K4B0L3306     3
# 37087M1X1N5918     3
# 37087K4B0L3960     3
# L4G0K206483405     2
# L4L4S690670525     2
# 89113L5N6A6619     2
# 33781L4Z2H2725     2
# L4L4S633069255     2
# 73179L8E2L8214     2
# L4G0K210452405     2
# 60827L4W5B2165     2
# 33172M6R1R1133     2
# L3R6E7851421079    2
# 78045M6K0E9300     2
# 37087L6Y5Z4612     2
# 27616K7S0C6440     2
# 33172K0K2G0420     2
# 35160L6T5R31458    2
# 30336L7N3G2175     2
# 37087L1Z1G1306     2
# L5S1J770433220     2
# M9W2Z428217221     2
# 37087L6Y5Z4320     2
# 02780N1K1E6310     2
# 75061K1G0Z6168     2
# 37087K4B0L3320     2
# 91342L5T2W9770     2
# L6C0Y3333121485    2
# K7P1T807036185     2
# M6A2W120109204     2
# 37087M1X1N5320     2
# 15001L4K3S2400     2
# 73179N8X5E7196     1
# 89115L5T2H7722     1
# 41042M5V1J12052    1
# 48079K0K3E0155     1
# 23703L4L9J71400    1
# 27020K0M2T0300     1
# 60131L7E2Y4509     1
# 69101N0L2H0175     1
# 37087M1X1N5280     1
# 30721L5E1E1712     1
# 14210L4K4W8763     1
# ...
